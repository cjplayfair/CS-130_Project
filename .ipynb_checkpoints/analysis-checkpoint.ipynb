# %%
#!type drugs.csv

# %%
# Load data from drugs.csv into the program
def load_data():
    list_data = []
    for line in open('drugs.csv'):
        cleaned_line = line.strip()
        cleaned_list = [item.strip('"') for item in cleaned_line.split(',')]
        list_data.append(cleaned_list)
    list_data.pop(0)
    return list_data
data = load_data()

# Load New York data from drugs.csv into the program
def load_data_NY():
    list_data = []
    for line in open('drugs.csv'):
        cleaned_line = line.strip()
        cleaned_list = [item.strip('"') for item in cleaned_line.split(',')]
        if 'New York' in cleaned_list:
            list_data.append(cleaned_list)
    #list_data.pop(0)
    return list_data
data2 = load_data_NY()

# %%
'''
How do substance abuse rates in New York compare to other states?
Create an averaged rate combining all substances for New York State. 
Assign a ranking list. 
Loop through every other state and if the state has a higher averaged rate, put it higher on the ranking list.
'''

def get_average_ny(data2):
    results_data_ny = []
    for nested_list in data2:
        # Get year
        year = nested_list[1]
        
        # Get alcohol rates
        average_alcohol_12_17 = "Alcohol 12-17: " + nested_list[8]
        average_alcohol_18_25 = "Alcohol 18-25: " + nested_list[9]
        average_alcohol_26 = "Alcohol 26+: " + nested_list[10]
    
        # Get cigarette rates
        average_cigarette_12_17 = "Cigarettes 12-17: " + nested_list[20]
        average_cigarette_18_25 = "Cigarettes 18-25: " + nested_list[21]
        average_cigarette_26 = "Cigarettes 26+: " + nested_list[22]
            
        # Get cocaine rates
        average_cocaine_12_17 = "Cocaine 12-17: " + nested_list[26]
        average_cocaine_18_25 = "Cocaine 18-25: " + nested_list[27]
        average_cocaine_26 = "Cocaine 26+: " + nested_list[28]

        # Get marijuana rates
        average_marijuana_12_17 = "Marijuana 12-17: " + nested_list[32]
        average_marijuana_18_25 = "Marijuana 18-25: " + nested_list[33]
        average_marijuana_26 = "Marijuana 18-25: " + nested_list[34]
    
        # Get tobacco rates
        average_tobacco_12_17 = "Tobacco 12-17: " + nested_list[50]
        average_tobacco_18_25 = "Tobacco 18-25: " + nested_list[51]
        average_tobacco_26 = "Tobacco 26+: " + nested_list[52]
        results_value = [year, average_alcohol_12_17, average_alcohol_18_25, average_alcohol_26, average_cigarette_12_17, average_cigarette_18_25, average_cigarette_26, average_cocaine_12_17, average_cocaine_18_25, average_cocaine_26, average_marijuana_12_17, average_marijuana_18_25, average_marijuana_26, average_tobacco_12_17, average_tobacco_18_25, average_tobacco_26]
        results_data_ny.append(results_value)
    return results_data_ny
NY_averages = get_average_ny(data2)
print(NY_averages)
# Out:
# [['2002', 'Alcohol 12-17: 55.929', 'Alcohol 18-25: 158.409', 'Alcohol 26+: 59.004', 'Cigarettes 12-17: 118.097', 'Cigarettes 18-25: 401.675', 'Cigarettes 26+: 247.615', 'Cocaine 12-17: 14.14', 'Cocaine 18-25: 69.253', 'Cocaine 26+: 20.154', 'Marijuana 12-17: 68.483', 'Marijuana 18-25: 80.16', 'Marijuana 18-25: 1.177', 'Tobacco 12-17: 127.82099999999998', 'Tobacco 18-25: 436.408', 'Tobacco 26+: 283.994'], ['2003', 'Alcohol 12-17: 54.891000000000005', 'Alcohol 18-25: 157.61700000000002', 'Alcohol 26+: 53.577', 'Cigarettes 12-17: 110.404', 'Cigarettes 18-25: 399.055', 'Cigarettes 26+: 241.084', 'Cocaine 12-17: 13.863', 'Cocaine 18-25: 76.00999999999999', 'Cocaine 26+: 18.262', 'Marijuana 12-17: 62.79600000000001', 'Marijuana 18-25: 76.523', 'Marijuana 18-25: 1.218', 'Tobacco 12-17: 124.926', 'Tobacco 18-25: 430.31399999999996', 'Tobacco 26+: 273.728'], ['2004', 'Alcohol 12-17: 53.769999999999996', 'Alcohol 18-25: 169.526', 'Alcohol 26+: 54.199999999999996', 'Cigarettes 12-17: 107.096', 'Cigarettes 18-25: 395.32099999999997', 'Cigarettes 26+: 238.09', 'Cocaine 12-17: 15.405999999999999', 'Cocaine 18-25: 73.502', 'Cocaine 26+: 18.057', 'Marijuana 12-17: 57.342', 'Marijuana 18-25: 65.307', 'Marijuana 18-25: 1.782', 'Tobacco 12-17: 127.407', 'Tobacco 18-25: 430.356', 'Tobacco 26+: 270.10699999999997'], ['2005', 'Alcohol 12-17: 52.898', 'Alcohol 18-25: 166.93800000000002', 'Alcohol 26+: 55.641000000000005', 'Cigarettes 12-17: 96.72500000000001', 'Cigarettes 18-25: 376.943', 'Cigarettes 26+: 237.953', 'Cocaine 12-17: 14.812000000000001', 'Cocaine 18-25: 73.407', 'Cocaine 26+: 22.082', 'Marijuana 12-17: 56.922', 'Marijuana 18-25: 63.175999999999995', 'Marijuana 18-25: 1.659', 'Tobacco 12-17: 119.16300000000001', 'Tobacco 18-25: 416.88199999999995', 'Tobacco 26+: 269.183'], ['2006', 'Alcohol 12-17: 46.523', 'Alcohol 18-25: 157.062', 'Alcohol 26+: 53.474000000000004', 'Cigarettes 12-17: 82.103', 'Cigarettes 18-25: 336.843', 'Cigarettes 26+: 223.153', 'Cocaine 12-17: 13.165', 'Cocaine 18-25: 70.581', 'Cocaine 26+: 22.069', 'Marijuana 12-17: 57.596000000000004', 'Marijuana 18-25: 67.558', 'Marijuana 18-25: 1.08', 'Tobacco 12-17: 103.48599999999999', 'Tobacco 18-25: 380.524', 'Tobacco 26+: 251.657'], ['2007', 'Alcohol 12-17: 47.593999999999994', 'Alcohol 18-25: 170.141', 'Alcohol 26+: 56.168', 'Cigarettes 12-17: 82.97699999999999', 'Cigarettes 18-25: 333.566', 'Cigarettes 26+: 207.612', 'Cocaine 12-17: 12.508000000000001', 'Cocaine 18-25: 64.631', 'Cocaine 26+: 20.877', 'Marijuana 12-17: 57.224', 'Marijuana 18-25: 67.316', 'Marijuana 18-25: 1.26', 'Tobacco 12-17: 104.421', 'Tobacco 18-25: 384.183', 'Tobacco 26+: 236.72899999999998'], ['2008', 'Alcohol 12-17: 53.117', 'Alcohol 18-25: 180.99699999999999', 'Alcohol 26+: 63.56', 'Cigarettes 12-17: 82.15', 'Cigarettes 18-25: 343.786', 'Cigarettes 26+: 205.47099999999998', 'Cocaine 12-17: 10.861', 'Cocaine 18-25: 73.087', 'Cocaine 26+: 20.194', 'Marijuana 12-17: 60.525000000000006', 'Marijuana 18-25: 73.843', 'Marijuana 18-25: 1.346', 'Tobacco 12-17: 107.34', 'Tobacco 18-25: 391.349', 'Tobacco 26+: 236.351'], ['2009', 'Alcohol 12-17: 49.692', 'Alcohol 18-25: 165.97', 'Alcohol 26+: 59.926', 'Cigarettes 12-17: 77.906', 'Cigarettes 18-25: 316.995', 'Cigarettes 26+: 209.12900000000002', 'Cocaine 12-17: 9.658', 'Cocaine 18-25: 64.24499999999999', 'Cocaine 26+: 16.692999999999998', 'Marijuana 12-17: 57.09', 'Marijuana 18-25: 74.30799999999999', 'Marijuana 18-25: 1.641', 'Tobacco 12-17: 99.77600000000001', 'Tobacco 18-25: 364.223', 'Tobacco 26+: 237.529'], ['2010', 'Alcohol 12-17: 41.565', 'Alcohol 18-25: 141.94', 'Alcohol 26+: 56.567', 'Cigarettes 12-17: 67.601', 'Cigarettes 18-25: 298.23499999999996', 'Cigarettes 26+: 211.514', 'Cocaine 12-17: 8.258', 'Cocaine 18-25: 50.01499999999999', 'Cocaine 26+: 14.524000000000001', 'Marijuana 12-17: 57.245999999999995', 'Marijuana 18-25: 72.11099999999999', 'Marijuana 18-25: 2.352', 'Tobacco 12-17: 88.726', 'Tobacco 18-25: 347.377', 'Tobacco 26+: 241.335999999999 ...
