# %%
# How do substance abuse rates in New York compare to other states? 

# Here I will import pandas to be used for dataframes on the CSV data
import pandas as pd
from labellines import labelLines
# drugs.csv will be the file I will be using for all my data
drugs = pd.read_csv("drugs.csv")
#Convert columns that are strings to integers for later comparisons
for col in drugs.columns:
    if drugs[col].dtype == 'string':
        drugs[col].str.strip()
        drugs[col] = pd.to_numeric(drugs[col], errors='coerce')

# %%
#Load in all the states with their respective rates
# * some states only have their rate for the past month, and some had past year
# This will create data frames for each state, only taking the specific rate data that I want to be used for my analysis
# It will also make the year the index and make sure all the values are floats, which will make data analysis much easier
drugsNY = drugs.loc[drugs.State == 'New York', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsNY = drugsNY.astype(float)
drugsNY = drugsNY.set_index('Year')
drugsAL = drugs.loc[drugs.State == 'Alabama', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsAL = drugsAL.astype(float)
drugsAL = drugsAL.set_index('Year')
drugsAK = drugs.loc[drugs.State == 'Alaska', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsAK = drugsAK.astype(float)
drugsAK = drugsAK.set_index('Year')
drugsAZ = drugs.loc[drugs.State == 'Arizona', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsAZ = drugsAZ.astype(float)
drugsAZ = drugsAZ.set_index('Year')
drugsAR = drugs.loc[drugs.State == 'Arkansas', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsAR = drugsAR.astype(float)
drugsAR = drugsAR.set_index('Year')
drugsCA = drugs.loc[drugs.State == 'California', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsCA = drugsCA.astype(float)
drugsCA = drugsCA.set_index('Year')
drugsCO = drugs.loc[drugs.State == 'Colorado', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsCO = drugsCO.astype(float)
drugsCO = drugsCO.set_index('Year')
drugsCT = drugs.loc[drugs.State == 'Connecticut', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsCT = drugsCT.astype(float)
drugsCT = drugsCT.set_index('Year')
drugsDE = drugs.loc[drugs.State == 'Delaware', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsDE = drugsDE.astype(float)
drugsDE = drugsDE.set_index('Year')
drugsFL = drugs.loc[drugs.State == 'Florida', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsFL = drugsFL.astype(float)
drugsFL = drugsFL.set_index('Year')
drugsGA = drugs.loc[drugs.State == 'Georgia', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsGA = drugsGA.astype(float)
drugsGA = drugsGA.set_index('Year')
drugsHI = drugs.loc[drugs.State == 'Hawaii', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsHI = drugsHI.astype(float)
drugsHI = drugsHI.set_index('Year')
drugsID = drugs.loc[drugs.State == 'Idaho', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsID = drugsID.astype(float)
drugsID = drugsID.set_index('Year')
drugsIL = drugs.loc[drugs.State == 'Illinois', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsIL = drugsIL.astype(float)
drugsIL = drugsIL.set_index('Year')
drugsIN = drugs.loc[drugs.State == 'Indiana', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsIN = drugsIN.astype(float)
drugsIN = drugsIN.set_index('Year')
drugsIA = drugs.loc[drugs.State == 'Iowa', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsIA = drugsIA.astype(float)
drugsIA = drugsIA.set_index('Year')
drugsKS = drugs.loc[drugs.State == 'Kansas', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsKS = drugsKS.astype(float)
drugsKS = drugsKS.set_index('Year')
drugsKY = drugs.loc[drugs.State == 'Kentucky', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsKY = drugsKY.astype(float)
drugsKY = drugsKY.set_index('Year')
drugsLA = drugs.loc[drugs.State == 'Louisiana', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsLA = drugsLA.astype(float)
drugsLA = drugsLA.set_index('Year')
drugsME = drugs.loc[drugs.State == 'Maine', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsME = drugsME.astype(float)
drugsME = drugsME.set_index('Year')
drugsMD = drugs.loc[drugs.State == 'Maryland', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsMD = drugsMD.astype(float)
drugsMD = drugsMD.set_index('Year')
drugsMA = drugs.loc[drugs.State == 'Massachusetts', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsMA = drugsMA.astype(float)
drugsMA = drugsMA.set_index('Year')
drugsMI = drugs.loc[drugs.State == 'Michigan', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsMI = drugsMI.astype(float)
drugsMI = drugsMI.set_index('Year')
drugsMN = drugs.loc[drugs.State == 'Minnesota', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsMN = drugsMN.astype(float)
drugsMN = drugsMN.set_index('Year')
drugsMS = drugs.loc[drugs.State == 'Mississippi', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsMS = drugsMS.astype(float)
drugsMS = drugsMS.set_index('Year')
drugsMO = drugs.loc[drugs.State == 'Missouri', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsMO = drugsMO.astype(float)
drugsMO = drugsMO.set_index('Year')
drugsMT = drugs.loc[drugs.State == 'Montana', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsMT = drugsMT.astype(float)
drugsMT = drugsMT.set_index('Year')
drugsNE = drugs.loc[drugs.State == 'Nebraska', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsNE = drugsNE.astype(float)
drugsNE = drugsNE.set_index('Year')
drugsNV = drugs.loc[drugs.State == 'Nevada', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsNV = drugsNV.astype(float)
drugsNV = drugsNV.set_index('Year')
drugsNH = drugs.loc[drugs.State == 'New Hampshire', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsNH = drugsNH.astype(float)
drugsNH = drugsNH.set_index('Year')
drugsNJ = drugs.loc[drugs.State == 'New Jersey', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsNJ = drugsNJ.astype(float)
drugsNJ = drugsNJ.set_index('Year')
drugsNM = drugs.loc[drugs.State == 'New Mexico', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsNM = drugsNM.astype(float)
drugsNM = drugsNM.set_index('Year')
drugsNC = drugs.loc[drugs.State == 'North Carolina', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsNC = drugsNC.astype(float)
drugsNC = drugsNC.set_index('Year')
drugsND = drugs.loc[drugs.State == 'North Dakota', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsND = drugsND.astype(float)
drugsND = drugsND.set_index('Year')
drugsOH = drugs.loc[drugs.State == 'Ohio', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsOH = drugsOH.astype(float)
drugsOH = drugsOH.set_index('Year')
drugsOK = drugs.loc[drugs.State == 'Oklahoma', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsOK = drugsOK.astype(float)
drugsOK = drugsOK.set_index('Year')
drugsOR = drugs.loc[drugs.State == 'Oregon', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsOR = drugsOR.astype(float)
drugsOR = drugsOR.set_index('Year')
drugsPA = drugs.loc[drugs.State == 'Pennsylvania', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsPA = drugsPA.astype(float)
drugsPA = drugsPA.set_index('Year')
drugsRI = drugs.loc[drugs.State == 'Rhode Island', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsRI = drugsRI.astype(float)
drugsRI = drugsRI.set_index('Year')
drugsSC = drugs.loc[drugs.State == 'South Carolina', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsSC = drugsSC.astype(float)
drugsSC = drugsSC.set_index('Year')
drugsSD = drugs.loc[drugs.State == 'South Dakota', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsSD = drugsSD.astype(float)
drugsSD = drugsSD.set_index('Year')
drugsTN = drugs.loc[drugs.State == 'Tennessee', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsTN = drugsTN.astype(float)
drugsTN = drugsTN.set_index('Year')
drugsTX = drugs.loc[drugs.State == 'Texas', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsTX = drugsTX.astype(float)
drugsTX = drugsTX.set_index('Year')
drugsUT = drugs.loc[drugs.State == 'Utah', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsUT = drugsUT.astype(float)
drugsUT = drugsUT.set_index('Year')
drugsVT = drugs.loc[drugs.State == 'Vermont', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsVT = drugsVT.astype(float)
drugsVT = drugsVT.set_index('Year')
drugsVA = drugs.loc[drugs.State == 'Virginia', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsVA = drugsVA.astype(float)
drugsVA = drugsVA.set_index('Year')
drugsWA = drugs.loc[drugs.State == 'Washington', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsWA = drugsWA.astype(float)
drugsWA = drugsWA.set_index('Year')
drugsWV = drugs.loc[drugs.State == 'West Virginia', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsWV = drugsWV.astype(float)
drugsWV = drugsWV.set_index('Year')
drugsWI = drugs.loc[drugs.State == 'Wisconsin', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsWI = drugsWI.astype(float)
drugsWI = drugsWI.set_index('Year')
drugsWY = drugs.loc[drugs.State == 'Wyoming', ['Year', 'Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']]
drugsWY = drugsWY.astype(float)
drugsWY = drugsWY.set_index('Year')

# %%
#Turn all the state dataframes into a dictionary for easy comparisons
# By having a dictionary of the data frames, I will be able to quickly find the difference in rates versus New York
state_DFs = {
    'Alabama': drugsAL,
    'Alaska': drugsAK,
    'Arizona': drugsAZ,
    'Arkansas': drugsAR,
    'California': drugsCA,
    'Colorado': drugsCO,
    'Connecticut': drugsCT,
    'Delaware': drugsDE,
    'Florida': drugsFL,
    'Georgia': drugsGA,
    'Hawaii': drugsHI,
    'Idaho': drugsID,
    'Illinois': drugsIL,
    'Indiana': drugsIN,
    'Iowa': drugsIA,
    'Kansas': drugsKS,
    'Kentucky': drugsKY,
    'Louisiana': drugsLA,
    'Maine': drugsME,
    'Maryland': drugsMD,
    'Massachusetts': drugsMA,
    'Michigan': drugsMI,
    'Minnesota': drugsMN,
    'Mississippi': drugsMS,
    'Missouri': drugsMO,
    'Montana': drugsMT,
    'Nebraska': drugsNE,
    'Nevada': drugsNV,
    'New Hampshire': drugsNH,
    'New Jersey': drugsNJ,
    'New Mexico': drugsNM,
    'North Carolina': drugsNC,
    'North Dakota': drugsND,
    'Ohio': drugsOH,
    'Oklahoma': drugsOK,
    'Oregon': drugsOR,
    'Pennsylvania': drugsPA,
    'Rhode Island': drugsRI,
    'South Carolina': drugsSC,
    'South Dakota': drugsSD,
    'Tennessee': drugsTN,
    'Texas': drugsTX,
    'Utah': drugsUT,
    'Vermont': drugsVT,
    'Virginia': drugsVA,
    'Washington': drugsWA,
    'West Virginia': drugsWV,
    'Wisconsin': drugsWI,
    'Wyoming': drugsWY
}

# %%
# Here I will start comparing the data by creating a new dictionary with all the compared data
# I will divide the rates of each state to the NY one, which will show how the rates have changed versus New York over time
drug_cols = ['Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']
# Dictionary to hold newly calculated comparison DataFrames
compared_DFs = {}
# Divide state DataFrame by the NY DataFrame
for state_name, state_DF in state_DFs.items():
    temp_state = state_DF.copy()
    ratio_DF = temp_state.div(drugsNY)
    compared_DFs[state_name] = ratio_DF

# Create master data frame with all the compared data, since the dictionary will be harder to use when making matplotlib plots
dfs_to_combine = []
for state_name, state_DF in compared_DFs.items():
    temp_DF = state_DF.copy()
    if temp_DF.index.name == 'Year' or 'Year' not in temp_DF.columns:
        temp_DF = temp_DF.reset_index()
    temp_DF.insert(0, 'State', state_name)
    dfs_to_combine.append(temp_DF)
master_DF = pd.concat(dfs_to_combine, ignore_index=True)

# %%
# Find 2018's highest alcohol usage relative to NY for 12-17, 18-25 and 26+
# Isolate target column into variable
target_column = 'Rates.Alcohol.Use Disorder Past Year.12-17'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Alcohol Rate Found for 12-17")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Alcohol.Use Disorder Past Year.18-25'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Alcohol Rate Found for 18-25")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Alcohol.Use Disorder Past Year.26+'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Alcohol Rate Found for 26+")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")
# Out:
# Absolute Highest Alcohol Rate Found for 12-17
# State: Montana
# Year: 2017.0
# Rate: 2.141705934576248
# Absolute Highest Alcohol Rate Found for 18-25
# State: North Dakota
# Year: 2003.0
# Rate: 1.7316723449881672
# Absolute Highest Alcohol Rate Found for 26+
# State: Wisconsin
# Year: 2003.0
# Rate: 1.7301453982119193

# %%
# Find 2018's highest cigarette usage relative to NY for 12-17, 18-25 and 26+
# Isolate target column into variable
target_column = 'Rates.Tobacco.Cigarette Past Month.12-17'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Cigarette Rate Found for 12-17")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Tobacco.Cigarette Past Month.18-25'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Cigarette Rate Found for 18-25")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Tobacco.Cigarette Past Month.26+'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Cigarette Rate Found for 26+")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")
# Out:
# Absolute Highest Cigarette Rate Found for 12-17
# State: Montana
# Year: 2018.0
# Rate: 3.182580424366872
# Absolute Highest Cigarette Rate Found for 18-25
# State: West Virginia
# Year: 2018.0
# Rate: 1.9122505632943694
# Absolute Highest Cigarette Rate Found for 26+
# State: West Virginia
# Year: 2017.0
# Rate: 1.9032364897333662

# %%
# Find 2018's highest cocaine usage relative to NY for 12-17, 18-25 and 26+
# Isolate target column into variable
target_column = 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Cocaine Rate Found for 12-17")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Cocaine Rate Found for 18-25")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Illicit Drugs.Cocaine Used Past Year.26+'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Cocaine Rate Found for 26+")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")
# Out:
# Absolute Highest Cocaine Rate Found for 12-17
# State: Vermont
# Year: 2015.0
# Rate: 2.527200353825741
# Absolute Highest Cocaine Rate Found for 18-25
# State: Vermont
# Year: 2016.0
# Rate: 2.1124997842186124
# Absolute Highest Cocaine Rate Found for 26+
# State: Colorado
# Year: 2018.0
# Rate: 1.612145597454852

# %%
# Find 2018's highest marijuana usage relative to NY for 12-17, 18-25 and 26+
# Isolate target column into variable
target_column = 'Rates.Marijuana.Used Past Year.12-17'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Marijuana Rate Found for 12-17")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Marijuana.Used Past Year.18-25'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Marijuana Rate Found for 18-25")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Marijuana.Used Past Year.26+'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Marijuana Rate Found for 26+")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")
# Out:
# Absolute Highest Marijuana Rate Found for 12-17
# State: Vermont
# Year: 2017.0
# Rate: 1.6560593688457659
# Absolute Highest Marijuana Rate Found for 18-25
# State: Vermont
# Year: 2010.0
# Rate: 1.4740998838559813
# Absolute Highest Marijuana Rate Found for 26+
# State: Oregon
# Year: 2016.0
# Rate: 2.1630092095096844

# %%
# Find 2018's highest tobacco usage relative to NY for 12-17, 18-25 and 26+
# Isolate target column into variable
target_column = 'Rates.Tobacco.Use Past Month.12-17'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Tobacco Rate Found for 12-17")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Tobacco.Use Past Month.18-25'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Tobacco Rate Found for 18-25")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")

# Isolate target column into variable
target_column = 'Rates.Tobacco.Use Past Month.26+'
#initialize values to keep track of highest record found
highest_value = -1
highest_state = None
highest_year = None
# Loop through each state
for state_name, state_DF in compared_DFs.items():
    if target_column in state_DF.columns:
        # find year where this state has its highest rate
        local_max_year = state_DF[target_column].idxmax()
        local_max_value = state_DF.loc[local_max_year, target_column]
        # If this state's peak rate is higher than our current overall record, update it
        if local_max_value > highest_value:
            highest_value = local_max_value
            highest_state = state_name
            highest_year = local_max_year
print("Absolute Highest Tobacco Rate Found for 26+")
print(f"State: {highest_state}")
print(f"Year: {highest_year}")
print(f"Rate: {highest_value}")
# Out:
# Absolute Highest Tobacco Rate Found for 12-17
# State: Kentucky
# Year: 2017.0
# Rate: 2.5849291784702553
# Absolute Highest Tobacco Rate Found for 18-25
# State: West Virginia
# Year: 2018.0
# Rate: 1.7639721152955805
# Absolute Highest Tobacco Rate Found for 26+
# State: West Virginia
# Year: 2017.0
# Rate: 1.9895290813404956

# %%
# Which States Were Mentioned the Most Compared to NYS?
highest12to17 = ['Montana 2x', 'Vermont 2x', 'Kentucky']
highest18to25 = ['West Virginia 2x', 'Vermont 2x', 'North Dakota']
highest26 = ['West Virginia 2x', 'Colorado', 'Oregon', 'Wisconsin']
mentionedTheMost = ['West Virginia 4x', 'Vermont 4x', 'Montana 2x']

# %%
# Matplotlib
import matplotlib.pyplot as plt
# Plot national average trend for each drug against NY
drug_cols = ['Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']
national_averages = master_DF.groupby('Year')[drug_cols].mean()
fig, ax = plt.subplots(figsize=(12,7))
for drug in drug_cols:
    ax.plot(national_averages.index, national_averages[drug], marker='o', linewidth=2, label=drug)
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=9)
ax.axhline(y=1.0, color='red', linestyle='--', linewidth=4, label="New York (Baseline)")
ax.set_title("US National Average Substance Abuse Ratios Over Time (Compared to NY)", fontsize=14, fontweight='bold')
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Ratio (Value > 1.0 means higher than NY)", fontsize=12)
ax.set_xticks(national_averages.index)
ax.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
#plt.savefig('National_Abuse_Rates.png')
plt.show()

# %%
# Plot national average for 12-17 against NY
national_averages = master_DF.groupby('Year')[drug_cols].mean()
fig, ax = plt.subplots(figsize=(12,7))
drug_cols = ['Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Tobacco.Use Past Month.12-17']
for drug in drug_cols:
    ax.plot(national_averages.index, national_averages[drug], marker='o', linewidth=2, label=drug)
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=9)
ax.axhline(y=1.0, color='red', linestyle='--', linewidth=4, label="New York (Baseline)")
ax.set_title("US National Average Substance Abuse Ratios Over Time Aged 12-17 (Compared to NY)", fontsize=14, fontweight='bold')
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Ratio (Value > 1.0 means higher than NY)", fontsize=12)
ax.set_xticks(national_averages.index)
ax.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
#plt.savefig('National12to17.png')
plt.show()

# %%
# Plot national average for 18-25 against NY
national_averages = master_DF.groupby('Year')[drug_cols].mean()
fig, ax = plt.subplots(figsize=(12,7))
drug_cols = ['Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Tobacco.Use Past Month.18-25']
for drug in drug_cols:
    ax.plot(national_averages.index, national_averages[drug], marker='o', linewidth=2, label=drug)
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=9)
ax.axhline(y=1.0, color='red', linestyle='--', linewidth=4, label="New York (Baseline)")
ax.set_title("US National Average Substance Abuse Ratios Over Time Ages 18-25 (Compared to NY)", fontsize=14, fontweight='bold')
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Ratio (Value > 1.0 means higher than NY)", fontsize=12)
ax.set_xticks(national_averages.index)
ax.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
#plt.savefig('National18to25.png')
plt.show()

# %%
# Plot national average for 26+ against NY
national_averages = master_DF.groupby('Year')[drug_cols].mean()
fig, ax = plt.subplots(figsize=(12,7))
drug_cols = ['Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.26+']
for drug in drug_cols:
    ax.plot(national_averages.index, national_averages[drug], marker='o', linewidth=2, label=drug)
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=9)
ax.axhline(y=1.0, color='red', linestyle='--', linewidth=4, label="New York (Baseline)")
ax.set_title("US National Average Substance Abuse Ratios Over Time Ages 26+ (Compared to NY)", fontsize=14, fontweight='bold')
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Ratio (Value > 1.0 means higher than NY)", fontsize=12)
ax.set_xticks(national_averages.index)
ax.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
#plt.savefig('National26+.png')
plt.show()

# %%
# Compare Montana versus New York alcohol 12-17
age_groups = ['Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']
age_group = 'Rates.Alcohol.Use Disorder Past Year.12-17'
target_state = 'Montana'
df_Montana = master_DF[master_DF.State == 'Montana']
montana_year = df_Montana['Year']
plt.figure(figsize=(10, 6))
plt.plot(montana_year, df_Montana[age_group], marker='o', color='b', linewidth=2, label=age_group)
plt.title("Montana Rate of Alcohol Use Disorder 12-17 vs New York")
plt.xlabel('Year', fontsize=12)
plt.ylabel('Rate', fontsize=12)
plt.xticks(montana_year, rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Compare Texas versus New York marijuana 12-17
age_groups = ['Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']
age_group = 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25'
target_state = 'Vermont'
df_Vermont = master_DF[master_DF.State == 'Vermont']
vermont_year = df_Vermont['Year']
plt.figure(figsize=(10, 6))
plt.plot(vermont_year, df_Vermont[age_group], marker='o', color='g', linewidth=2, label=age_group)
plt.title("Vermont Rate of Cocaine Use Age 18-25 vs New York")
plt.xlabel('Year', fontsize=12)
plt.ylabel('Rate', fontsize=12)
plt.xticks(texas_year, rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Compare Florida versus New York Cocaine 12-17
age_groups = ['Rates.Alcohol.Use Disorder Past Year.12-17', 'Rates.Alcohol.Use Disorder Past Year.18-25', 'Rates.Alcohol.Use Disorder Past Year.26+', 'Rates.Tobacco.Cigarette Past Month.12-17', 'Rates.Tobacco.Cigarette Past Month.18-25', 'Rates.Tobacco.Cigarette Past Month.26+', 'Rates.Illicit Drugs.Cocaine Used Past Year.12-17', 'Rates.Illicit Drugs.Cocaine Used Past Year.18-25', 'Rates.Illicit Drugs.Cocaine Used Past Year.26+', 'Rates.Marijuana.Used Past Year.12-17', 'Rates.Marijuana.Used Past Year.18-25', 'Rates.Marijuana.Used Past Year.26+', 'Rates.Tobacco.Use Past Month.12-17', 'Rates.Tobacco.Use Past Month.18-25', 'Rates.Tobacco.Use Past Month.26+']
age_group = 'Rates.Marijuana.Used Past Year.26+'
target_state = 'Oregon'
df_Oregon = master_DF[master_DF.State == 'Oregon']
oregon_year = df_Oregon['Year']
plt.figure(figsize=(10, 6))
plt.plot(oregon_year, df_Oregon[age_group], marker='o', color='r', linewidth=2, label=age_group)
plt.title("Oregon Rate of Marijuana Use Age 26+ vs New York")
plt.xlabel('Year', fontsize=12)
plt.ylabel('Rate', fontsize=12)
plt.xticks(florida_year, rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
